# %%
import os
import warnings
warnings.filterwarnings('ignore')

import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split, cross_val_score, GridSearchCV
from sklearn.preprocessing import StandardScaler
from sklearn.feature_selection import SelectKBest, mutual_info_regression
from sklearn.pipeline import Pipeline
from sklearn.ensemble import GradientBoostingRegressor, RandomForestRegressor
from sklearn.linear_model import Ridge
from xgboost import XGBRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import matplotlib.pyplot as plt
import seaborn as sns

# Constants
RANDOM_STATE = 42
CSV_PATH = 'scenario1_fixed_intensity_data_50000.csv'
FIRST_N_MINUTES = 20  
SAMPLE_INTERVAL_MIN = 5
STEPS = int(FIRST_N_MINUTES / SAMPLE_INTERVAL_MIN)
TRAIN_CELLS = 30000

# Utility functions
def find_columns(df):
    possible_id = ['storm_id', 'cell_id', 'cellID', 'ID', 'stormID', 'cellId']
    possible_time = ['timestamp', 'time', 'datetime', 'date_time', 'ts', 'timestamp_utc']
    id_col = next((c for c in possible_id if c in df.columns), None)
    time_col = next((c for c in possible_time if c in df.columns), None)
    return id_col, time_col

def load_data(path):
    if not os.path.exists(path):
        raise FileNotFoundError(f"CSV not found at {path}.")
    df = pd.read_csv(path)
    id_col, time_col = find_columns(df)
    if time_col is None:
        df['__time_index__'] = df.groupby(id_col).cumcount()
        time_col = '__time_index__'
    else:
        try:
            df[time_col] = pd.to_datetime(df[time_col])
        except Exception:
            pass
    return df, id_col, time_col

def summary_statistics(df, id_col, time_col):
    vars_of_interest = ['lifetime_hours', 'intensity_dbz', 'rainfall_mm_per_hr', 'intensity_change_rate']
    available = [v for v in vars_of_interest if v in df.columns]
    print("Summary Statistics for Variables:")
    display(pd.DataFrame({v: df[v].describe() for v in available}))
    agg = df.groupby(id_col).agg(
        lifetime_hours=('lifetime_hours', 'first') if 'lifetime_hours' in df.columns else (
            time_col, lambda x: (x.max() - x.min()).total_seconds()/3600 
            if np.issubdtype(x.dtype, np.datetime64) else np.nan
        ),
        peak_intensity=('intensity_dbz', 'max'),
        peak_rainfall=('rainfall_mm_per_hr', 'max'),
        total_rainfall_mm=('rainfall_mm_per_hr', lambda x: (x * (SAMPLE_INTERVAL_MIN / 60.0)).sum())
    )
    print("Aggregated Statistics by Storm Cell:")
    display(agg.describe().T)
    return agg

def create_visualizations(df, id_col, time_col):
    vars_plot = [c for c in ['intensity_dbz', 'rainfall_mm_per_hr', 'intensity_change_rate'] if c in df.columns]
    for v in vars_plot:
        plt.figure(figsize=(8, 6))
        plt.hist(df[v].dropna(), bins=80)
        plt.title(f'Histogram of {v}')
        plt.xlabel(v)
        plt.ylabel('Frequency')
        plt.show()

def extract_first_n_features(df, id_col, time_col, steps=STEPS):
    feature_rows = []
    for sid, sub in df.groupby(id_col, sort=False):
        sub = sub.sort_values(time_col).head(steps)
        feat = {'storm_id': sid}
        for col in ['intensity_dbz', 'rainfall_mm_per_hr', 'intensity_change_rate']:
            if col in sub.columns:
                vals = sub[col].values
                feat[f'{col}_t0'] = vals[0]
                feat[f'{col}_tlast'] = vals[-1]
                feat[f'{col}_delta'] = vals[-1] - vals[0]
                feat[f'{col}_mean'] = np.nanmean(vals)
                feat[f'{col}_std'] = np.nanstd(vals)
                if len(vals) > 1:
                    x = np.arange(len(vals))
                    A = np.vstack([x, np.ones(len(x))]).T
                    m, _ = np.linalg.lstsq(A, vals, rcond=None)[0]
                    feat[f'{col}_slope'] = m
                else:
                    feat[f'{col}_slope'] = 0.0
                feat[f'{col}_lag1'] = sub[col].shift(1).iloc[1] if len(sub) > 1 else np.nan
        if 'x_position' in sub.columns and 'y_position' in sub.columns:
            feat['speed'] = np.sqrt((sub['x_position'].diff()**2 + sub['y_position'].diff()**2).mean()) / (SAMPLE_INTERVAL_MIN / 60) if len(sub) > 1 else 0.0
            feat['direction'] = np.arctan2(sub['y_position'].diff().mean(), sub['x_position'].diff().mean()) if len(sub) > 1 else 0.0
        if 'intensity_dbz' in sub.columns and 'size_pixels' in sub.columns:
            feat['intensity_size_interaction'] = sub['intensity_dbz'].mean() * sub['size_pixels'].mean()
        if 'time_since_formation_hours' in sub.columns and 'lifetime_hours' in sub.columns:
            feat['time_progress_ratio'] = sub['time_since_formation_hours'].mean() / sub['lifetime_hours'].iloc[0]
        feature_rows.append(feat)
    return pd.DataFrame(feature_rows).set_index('storm_id').fillna(0)

def compute_targets(df, id_col, time_col):
    rows = []
    for sid, sub in df.groupby(id_col, sort=False):
        sub = sub.sort_values(time_col)
        lifetime_h = sub['lifetime_hours'].iloc[0]
        peak_rain = sub['rainfall_mm_per_hr'].max()
        total_rain = (sub['rainfall_mm_per_hr'] * (SAMPLE_INTERVAL_MIN / 60.0)).sum()
        rows.append({
            'storm_id': sid,
            'lifetime_hours_true': lifetime_h,
            'peak_rainfall_mm_per_hr_true': peak_rain,
            'total_rainfall_mm_true': total_rain
        })
    return pd.DataFrame(rows).set_index('storm_id')

def regression_metrics(y_true, y_pred):
    mae = mean_absolute_error(y_true, y_pred)
    rmse = mean_squared_error(y_true, y_pred, squared=False)
    r2 = r2_score(y_true, y_pred)
    mape = np.mean(np.abs((y_true - y_pred) / np.maximum(np.abs(y_true), 1e-6))) * 100
    return {'MAE': mae, 'RMSE': rmse, 'R2': r2, 'MAPE%': mape}

# Load & process data
df, id_col, time_col = load_data(CSV_PATH)
agg_stats = summary_statistics(df, id_col, time_col)
create_visualizations(df, id_col, time_col)

feats = extract_first_n_features(df, id_col, time_col, steps=STEPS)
targets = compute_targets(df, id_col, time_col)
data = feats.join(targets, how='inner').dropna()

# --- FIXED TRAIN/TEST SPLIT ---
train_ids, test_ids = train_test_split(
    list(data.index),
    train_size=TRAIN_CELLS,
    random_state=RANDOM_STATE
)

X = data.drop(columns=['lifetime_hours_true', 'peak_rainfall_mm_per_hr_true', 'total_rainfall_mm_true'])
y_life = data['lifetime_hours_true']
y_peak = data['peak_rainfall_mm_per_hr_true']
y_total = data['total_rainfall_mm_true']

X_train, X_test = X.loc[train_ids], X.loc[test_ids]
y_train_life, y_test_life = y_life.loc[train_ids], y_life.loc[test_ids]
y_train_peak, y_test_peak = y_peak.loc[train_ids], y_peak.loc[test_ids]
y_train_total, y_test_total = y_total.loc[train_ids], y_total.loc[test_ids]

# Model setup
selector = SelectKBest(score_func=mutual_info_regression, k=min(10, X_train.shape[1]))
scaler = StandardScaler()
models = {
    'GB': GradientBoostingRegressor(random_state=RANDOM_STATE),
    'RF': RandomForestRegressor(n_estimators=100, random_state=RANDOM_STATE, n_jobs=-1),
    'Ridge': Ridge(random_state=RANDOM_STATE),
    'XGB': XGBRegressor(random_state=RANDOM_STATE)
}
param_grid = {
    'GB': {'model__n_estimators': [100, 200], 'model__learning_rate': [0.01, 0.1], 'model__max_depth': [3, 5]},
    'XGB': {'model__n_estimators': [100, 200], 'model__learning_rate': [0.01, 0.1], 'model__max_depth': [3, 5]},
    'RF': {'model__n_estimators': [100, 200], 'model__max_depth': [None, 10]},
    'Ridge': {'model__alpha': [0.1, 1.0, 10.0]}
}

# Run models
results = []
for name, model in models.items():
    for target_name, y_train, y_test in [
        ('lifetime', y_train_life, y_test_life),
        ('peak', y_train_peak, y_test_peak),
        ('total', y_train_total, y_test_total)
    ]:
        pipe = Pipeline([('select', selector), ('scale', scaler), ('model', model)])
        grid = GridSearchCV(pipe, param_grid[name], cv=5, scoring='r2', n_jobs=-1)
        grid.fit(X_train, y_train)
        print(f"Best parameters for {name} - {target_name}: {grid.best_params_}")
        
        pred = grid.predict(X_test)
        metrics = regression_metrics(y_test.values, pred)
        print(f"{name} - {target_name}: {metrics}")
        results.append({'model': name, 'target': target_name, **metrics})
        
        cv_scores = cross_val_score(grid.best_estimator_, X_train, y_train, cv=5, scoring='r2')
        print(f"Cross-validated R2 for {name} - {target_name}: {cv_scores.mean():.4f} ± {cv_scores.std():.4f}")
        
        if hasattr(grid.best_estimator_.named_steps['model'], 'feature_importances_'):
            importances = grid.best_estimator_.named_steps['model'].feature_importances_
            selected_features = X_train.columns[grid.best_estimator_.named_steps['select'].get_support()]
            print(f"Feature Importances for {name} - {target_name}:")
            display(pd.DataFrame({'Feature': selected_features, 'Importance': importances}).sort_values('Importance', ascending=False))
        
        plt.figure(figsize=(8, 6))
        residuals = y_test - pred
        plt.scatter(y_test, residuals, alpha=0.5)
        plt.axhline(0, color='red', linestyle='--')
        plt.xlabel(f'Actual {target_name}')
        plt.ylabel('Residuals')
        plt.title(f'Residual Plot for {name} - {target_name}')
        plt.show()

results_df = pd.DataFrame(results)
print("Final Results:")
display(results_df)
# Out:
# Summary Statistics for Variables:
#        lifetime_hours  intensity_dbz  rainfall_mm_per_hr  \
# count    1.164799e+06   1.164799e+06        1.164799e+06
# mean     1.896717e+00   3.313981e+01        2.254249e+01
# std      1.606759e-01   1.992297e+01        1.680973e+01
# min      7.901251e-01   2.677140e-01        0.000000e+00
# 25%      1.830661e+00   1.211763e+01        4.732527e+00
# 50%      2.000000e+00   3.696603e+01        2.319101e+01
# 75%      2.000000e+00   4.515041e+01        3.170050e+01
# max      2.000000e+00   6.735650e+01        5.995287e+01
#
#        intensity_change_rate
# count           1.164799e+06
# mean            1.731522e+01
# std             8.126909e+01
# min            -1.465160e+02
# 25%            -3.494264e+01
# 50%             4.115665e+00
# 75%             3.984524e+01
# max             3.448117e+02
# Aggregated Statistics by Storm Cell:
#                      count       mean       std        min        25%  \
# lifetime_hours     50000.0   1.879611  0.175547   0.790125   1.795764
# peak_intensity     50000.0  67.101862  1.020798  58.948614  67.356503
# peak_rainfall      50000.0  58.606309  1.511296  47.488479  58.356545
# total_rainfall_mm  50000.0  43.762459  4.639333  17.037659  41.008970
#
#                          50%        75%        max
# lifetime_hours      1.997884   2.000000   2.000000
# peak_intensity     67.356503  67.356503  67.356503
# peak_rainfall      58.896596  59.425257  59.952870
# total_rainfall_mm  46.140281  47.204155  48.030158
# Best parameters for GB - lifetime: {'model__learning_rate': 0.1, 'model__max_depth': 5, 'model__n_estimators': 200}
# GB - lifetime: {'MAE': np.float64(0.0001504921552617924), 'RMSE': np.float64(0.0004627301847933867), 'R2': 0.9999930915810847, 'MAPE%': np.float64(0.009474404794394346)}
# Cross-validated R2 for GB - lifetime: 1.0000 ± 0.0000
# Feature Importances for GB - lifetime:
#                        Feature    Importance
# 9          time_progress_ratio  9.999888e-01
# 8   intensity_size_interaction  6.052057e-06
# 0           intensity_dbz_mean  3.388647e-06
# 1            intensity_dbz_std  1.385938e-06
# 4  intensity_change_rate_delta  1.740948e-07
# 7  intensity_change_rate_slope  1.227776e-07
# 2          intensity_dbz_slope  4.583667e-08
# 5   intensity_change_rate_mean  1.820317e-08
# 3  intensity_change_rate_tlast  1.135918e-08
# 6    intensity_change_rate_std  5.127040e-10
# Best parameters for GB - peak: {'model__learning_rate': 0.1, 'model__max_depth': 3, 'model__n_estimators': 200}
# GB - peak: {'MAE': np.float64(0.5030244392012361), 'RMSE': np.float64(0.587436041971537), 'R2': 0.8500655023299353, 'MAPE%': np.float64(0.8594519561119868)}
# Cross-validated R2 for GB - peak: 0.8425 ± 0.0071
# Feature Importances for GB - peak:
#                        Feature  Importance
# 9          time_progress_ratio    0.998759
# 2            intensity_dbz_std    0.000269
# 0          intensity_dbz_tlast    0.000200
# 3          intensity_dbz_slope    0.000180
# 4  intensity_change_rate_tlast    0.000175
# 5  intensity_change_rate_delta    0.000140
# 6   intensity_change_rate_mean    0.000116
# 1          intensity_dbz_delta    0.000082
# 7    intensity_change_rate_std    0.000053
# 8  intensity_change_rate_slope    0.000024
# Best parameters for GB - total: {'model__learning_rate': 0.1, 'model__max_depth': 5, 'model__n_estimators': 100}
# GB - total: {'MAE': np.float64(0.17895244249615336), 'RMSE': np.float64(0.22783662784300954), 'R2': 0.9976025426810595, 'MAPE%': np.float64(0.41341538355155166)}
# Cross-validated R2 for GB - total: 0.9976 ± 0.0001
# Feature Importances for GB - total:
#                        Feature  Importance
# 9          time_progress_ratio    0.997821
# 0           intensity_dbz_mean    0.000532
# 8   intensity_size_interaction    0.000478
# 5   intensity_change_rate_mean    0.000321
# 3  intensity_change_rate_tlast    0.000301
# 2          intensity_dbz_slope    0.000290
# 6    intensity_change_rate_std    0.000145
# 7  intensity_change_rate_slope    0.000102
# 1            intensity_dbz_std    0.000006
# 4  intensity_change_rate_delta    0.000004
# Best parameters for RF - lifetime: {'model__max_depth': None, 'model__n_estimators': 200}
# RF - lifetime: {'MAE': np.float64(2.5938860062889036e-05), 'RMSE': np.float64(0.00046129570261576973), 'R2': 0.9999931343474459, 'MAPE%': np.float64(0.0021701740306593613)}
# Cross-validated R2 for RF - lifetime: 1.0000 ± 0.0000
# Feature Importances for RF - lifetime:
#                        Feature  Importance
# 9          time_progress_ratio    0.999911
# 2            intensity_dbz_std    0.000024
# 4  intensity_change_rate_tlast    0.000023
# 8   intensity_size_interaction    0.000017
# 7  intensity_change_rate_slope    0.000006
# 5  intensity_change_rate_delta    0.000004
# 1           intensity_dbz_mean    0.000004
# 3          intensity_dbz_slope    0.000004
# 0          intensity_dbz_delta    0.000003
# 6    intensity_change_rate_std    0.000002
# Best parameters for RF - peak: {'model__max_depth': 10, 'model__n_estimators': 200}
# RF - peak: {'MAE': np.float64(0.5054603148635112), 'RMSE': np.float64(0.59124481120248), 'R2': 0.8481149335007113, 'MAPE%': np.float64(0.8637067356489383)}
# Cross-validated R2 for RF - peak: 0.8397 ± 0.0059
# Feature Importances for RF - peak:
#                        Feature    Importance
# 9          time_progress_ratio  9.997017e-01
# 1          intensity_dbz_delta  6.465356e-05
# 6   intensity_change_rate_mean  5.426826e-05
# 2            intensity_dbz_std  5.147131e-05
# 4  intensity_change_rate_tlast  3.880238e-05
# 7    intensity_change_rate_std  3.627026e-05
# 0          intensity_dbz_tlast  2.803513e-05
# 3          intensity_dbz_slope  1.404632e-05
# 5  intensity_change_rate_delta  1.058988e-05
# 8  intensity_change_rate_slope  1.476233e-07
# Best parameters for RF - total: {'model__max_depth': 10, 'model__n_estimators': 200}
# RF - total: {'MAE': np.float64(0.17957228819509233), 'RMSE': np.float64(0.2275745069766076), 'R2': 0.9976080559481931, 'MAPE%': np.float64(0.41535282166580795)}
# Cross-validated R2 for RF - total: 0.9975 ± 0.0001
# Feature Importances for RF - total:
#                        Feature  Importance
# 9          time_progress_ratio    0.998345
# 8   intensity_size_interaction    0.000407
# 0           intensity_dbz_mean    0.000327
# 4  intensity_change_rate_delta    0.000191
# 3  intensity_change_rate_tlast    0.000150
# 2          intensity_dbz_slope    0.000136
# 7  intensity_change_rate_slope    0.000134
# 6    intensity_change_rate_std    0.000130
# 1            intensity_dbz_std    0.000092
# 5   intensity_change_rate_mean    0.000087
# Best parameters for Ridge - lifetime: {'model__alpha': 0.1}
# Ridge - lifetime: {'MAE': np.float64(0.008908349464909678), 'RMSE': np.float64(0.013070940636845635), 'R2': 0.9944876512216598, 'MAPE%': np.float64(0.5213648566471063)}
# Cross-validated R2 for Ridge - lifetime: 0.9953 ± 0.0003
# Best parameters for Ridge - peak: {'model__alpha': 0.1}
# Ridge - peak: {'MAE': np.float64(0.8924829303214976), 'RMSE': np.float64(1.424761917223811), 'R2': 0.1180073064452869, 'MAPE%': np.float64(1.566163736702914)}
# Cross-validated R2 for Ridge - peak: 0.1259 ± 0.0112
# Best parameters for Ridge - total: {'model__alpha': 0.1}
# Ridge - total: {'MAE': np.float64(0.7399212144288917), 'RMSE': np.float64(0.9975984867455283), 'R2': 0.9540362599849296, 'MAPE%': np.float64(1.8078847810446017)}
# Cross-validated R2 for Ridge - total: 0.9547 ± 0.0008
# Best parameters for XGB - lifetime: {'model__learning_rate': 0.1, 'model__max_depth': 5, 'model__n_estimators': 100}
# XGB - lifetime: {'MAE': np.float64(0.0005265749544687564), 'RMSE': np.float64(0.0025639298721722437), 'R2': 0.9997879026273977, 'MAPE%': np.float64(0.03666476961695591)}
# Cross-validated R2 for XGB - lifetime: 0.9998 ± 0.0001
# Feature Importances for XGB - lifetime:
#                        Feature  Importance
# 9          time_progress_ratio    0.848567
# 1           intensity_dbz_mean    0.141302
# 0          intensity_dbz_tlast    0.009387
# 8   intensity_size_interaction    0.000720
# 2            intensity_dbz_std    0.000024
# 3          intensity_dbz_slope    0.000000
# 5  intensity_change_rate_delta    0.000000
# 4  intensity_change_rate_tlast    0.000000
# 7  intensity_change_rate_slope    0.000000
# 6    intensity_change_rate_std    0.000000
# Best parameters for XGB - peak: {'model__learning_rate': 0.1, 'model__max_depth': 3, 'model__n_estimators': 100}
# XGB - peak: {'MAE': np.float64(0.5440395145197573), 'RMSE': np.float64(0.7031363024517387), 'R2': 0.7851875578037177, 'MAPE%': np.float64(0.9329440705032912)}
# Cross-validated R2 for XGB - peak: 0.7768 ± 0.0163
# Feature Importances for XGB - peak:
#                        Feature  Importance
# 9          time_progress_ratio    0.983468
# 0          intensity_dbz_tlast    0.015452
# 2            intensity_dbz_std    0.001080
# 1          intensity_dbz_delta    0.000000
# 4  intensity_change_rate_tlast    0.000000
# 3          intensity_dbz_slope    0.000000
# 5  intensity_change_rate_delta    0.000000
# 6   intensity_change_rate_mean    0.000000
# 7    intensity_change_rate_std    0.000000
# 8  intensity_change_rate_slope    0.000000
# Best parameters for XGB - total: {'model__learning_rate': 0.1, 'model__max_depth': 3, 'model__n_estimators': 200}
# XGB - total: {'MAE': np.float64(0.19898099475123174), 'RMSE': np.float64(0.282982757356645), 'R2': 0.9963015160013087, 'MAPE%': np.float64(0.47178581313612405)}
# Cross-validated R2 for XGB - total: 0.9962 ± 0.0002
# Feature Importances for XGB - total:
#                        Feature  Importance
# 9          time_progress_ratio    0.874971
# 0           intensity_dbz_mean    0.119806
# 8   intensity_size_interaction    0.005204
# 1            intensity_dbz_std    0.000019
# 2          intensity_dbz_slope    0.000000
# 3  intensity_change_rate_tlast    0.000000
# 5   intensity_change_rate_mean    0.000000
# 4  intensity_change_rate_delta    0.000000
# 7  intensity_change_rate_slope    0.000000
# 6    intensity_change_rate_std    0.000000
# Final Results:
#     model    target       MAE      RMSE        R2     MAPE%
# 0      GB  lifetime  0.000150  0.000463  0.999993  0.009474
# 1      GB      peak  0.503024  0.587436  0.850066  0.859452
# 2      GB     total  0.178952  0.227837  0.997603  0.413415
# 3      RF  lifetime  0.000026  0.000461  0.999993  0.002170
# 4      RF      peak  0.505460  0.591245  0.848115  0.863707
# 5      RF     total  0.179572  0.227575  0.997608  0.415353
# 6   Ridge  lifetime  0.008908  0.013071  0.994488  0.521365
# 7   Ridge      peak  0.892483  1.424762  0.118007  1.566164
# 8   Ridge     total  0.739921  0.997598  0.954036  1.807885
# 9     XGB  lifetime  0.000527  0.002564  0.999788  0.036665
# 10    XGB      peak  0.544040  0.703136  0.785188  0.932944
# 11    XGB     total  0.198981  0.282983  0.996302  0.471786
